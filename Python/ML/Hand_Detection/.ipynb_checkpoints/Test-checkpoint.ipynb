# %%
import glob
import os.path
import queue
import random
import string
import time

import cv2
import matplotlib.pyplot as plt
import numpy as np
import requests
import scipy

def imageSplitter(img, x, y):
    split = np.empty((y, x))
    print(len(img[0]), len(img))
    xStep, yStep = len(img[0])//(1 + x), len(img)//(1 + y)
    for i in range(x):
        for j in range(y):
            snip = img[j*yStep:(j+2)*yStep,i*xStep:(i+2)*xStep]
            split[j, i] = 

    return split

# %%
example = cv2.imread("Train/Hands/107492_hand.jpg")

# %%
plt.imshow(example)

# %%
x = imageSplitter(example, 3, 2)
# Out:
# 150 150
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-66b3ae379703> in <module>()
# ----> 1 x = imageSplitter(example, 3, 2)
#
# <ipython-input-6-5eae37391ac2> in imageSplitter(img, x, y)
#      18     for i in range(x):
#      19         for j in range(y):
# ---> 20             split[j, i] = img[j*yStep:(j+2)*yStep,i*xStep:(i+2)*xStep]
#      21
#      22     return split
#
# ValueError: setting an array element with a sequence.
